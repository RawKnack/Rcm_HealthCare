# %%
# %sql
drop table if exists healthcarercm_adb_ws.audit.load_logs

# %%
# %sql
create schema if not exists healthcarercm_adb_ws.audit;
CREATE TABLE IF NOT EXISTS healthcarercm_adb_ws.audit.load_logs (
    id BIGINT GENERATED ALWAYS AS IDENTITY,
    data_source STRING,
    tablename STRING,
    numberofrowscopied INT,
    watermarkcolumnname STRING,
    loaddate TIMESTAMP
);

# %%
# %sql
select * from audit.load_logs
